# %% [markdown]
# <a href="https://colab.research.google.com/github/Mudit727/ISYS2001/blob/main/Week%202/Project_02_Finance_Tracker_Profile_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# # Personal Finance Tracker – Profile Setup
#
# Student Name: Mudit Bhalla
# Course: Introduction to Programming
# Project: Finance Tracker Profile Setup
#
# This notebook creates the first component of a Personal Finance Tracker application.
# The program collects user preferences and generates a personalized welcome message.
# ---

# %% [markdown]
# ## Step 1 – State the Problem
#
# Define the goal of your program in your own words:
#
# - **Goal:** The goal of this program is to create a simple user profile setup for a Personal Finance Tracker application. The program collects basic user preferences and displays a personalized welcome message.
#
# - **Data to Gather:**
# User's name,
# Preferred theme color for the app,
# primary currency,
# Main savings goal.

# %% [raw]
# ---
#
# ## Step 2 – Describe Input and Output
#
# **Inputs:**
# - `user_name` (string) - The user's name
# - `theme_color` (string)- Preferred theme color
# - `primary_currency` (string)- Currency used for financial tracking
# - `main_savings_goal` (string)- User's main savings goal
#
# **Expected Output:**
#  A personalized weclome message summarizing the user's profile.
#
# > "Welcome to your Personal Finance Tracker, [user_name]! Your profile is ready. The app will use a [theme_color] theme and all amounts will be in [primary_currency]. Let's start working towards your goal of saving for a [main_savings_goal]!"

# %% [markdown]
# ## Step 3 – Work the Problem by Hand
#
# Exmple Inputs:
#
# - `user_name` = "Alex"
# - `theme_color` = "dark"
# - `primary_currency` = "AUD"
# - `main_savings_goal` = "a holiday"
#
# Example Expected output is:
#
# > "Welcome to your Personal Finance Tracker, Alex!
# Your profile is ready.
# The app will use a dark theme and all amounts will be in AUD.
#  Let's start working towards your goal of saving for a a holiday!"

# %% [markdown]
# ---
#
# ## Step 4 – Develop an Algorithm (Pseudocode)
#
# Outline your approach using pseudocode. For example:
#
# ```plain
#
# 1. Start the program
# 2. Ask the user for their name
# 3. Store the name in a variable called user_name
# 4. Ask the user for their preferred theme color
# 5. Store it in theme_color
# 6. Ask the user for their primary currency
# 7. Store it in primary_currency
# 8. Ask the user for their main savings goal
# 9. Store it in main_savings_goal
# 10. Create a welcome message using these variables
# 11. Print the welcome message
# 12. End the program
# ```
#
#
# ---

# %%
# Import datetime to timestamp your work
from datetime import datetime

# Collect user information for their financial profile
user_name = input("What is your name? ")
theme_color = input("What color would you like for your app theme? (e.g., blue, green, dark) ")
primary_currency = input("What is your primary currency? (e.g., AUD, USD, EUR) ")
main_savings_goal = input("What is one big savings goal you have? (e.g., New Car, Holiday) ")

# Construct the personalized welcome message
summary = ("Welcome to your Personal Finance Tracker, " + user_name + "! Your profile is ready. " + \
           "The app will use a " + theme_color + " theme and all amounts will be in " + \
           primary_currency + ". Let's start working towards your goal of saving for a " + \
           main_savings_goal + "!")

# Display the summary message
print(summary)
# Out:
# What is your name? Mudit
# What color would you like for your app theme? (e.g., blue, green, dark) Green
# What is your primary currency? (e.g., AUD, USD, EUR) AUD
# What is one big savings goal you have? (e.g., New Car, Holiday) 10000
# Welcome to your Personal Finance Tracker, Mudit! Your profile is ready. The app will use a Green theme and all amounts will be in AUD. Let's start working towards your goal of saving for a 10000!

# %% [markdown]
# ---
#
# ## 📋 Evidence Package for Lab Exit Ticket
#
# Complete the following evidence package to document your work and reflect on the process. This will be checked at the start of the next lab.

# %%
# Complete this dictionary with your reflections.

from datetime import datetime
evidence_package = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "student_name": "Mudit Bhalla",
    "project_context": "This project involved creating the initial user profile for a personal finance tracker, focusing on applying a structured problem-solving methodology.",
    "ai_tool_used": "Gemini,",
    "ai_assistance_summary": "I used ChatGPT to review my pseudocode and help improve the structure of my documentation and welcome message.",
    "best_practice_reflection": "Using descriptive variable names such as user_name and primary_currency made the code easier to understand and maintain.",
    "key_learning": "I learned that working through the problem step by step before coding made the program easier to implement and reduced mistakes."
}

# Display your evidence package
print("="*50)
print("EVIDENCE PACKAGE SUBMISSION")
print("="*50)
for key, value in evidence_package.items():
    # Format multi-line strings for better readability
    if isinstance(value, str) and len(value) > 60:
        print(f'\n{key.replace("_", " ").title()}:\n  {value}')
    else:
        print(f'{key.replace("_", " ").title()}: {value}')
print("="*50)
# Out:
# ...
# EVIDENCE PACKAGE SUBMISSION
# ...
# Timestamp: 2026-03-12 03:57:19
# Student Name: Mudit Bhalla
#
# Project Context:
#   This project involved creating the initial user profile for a personal finance tracker, focusing on applying a structured problem-solving methodology.
# Ai Tool Used: Gemini,
#
# Ai Assistance Summary:
#   I used ChatGPT to review my pseudocode and help improve the structure of my documentation and welcome message.
#
# Best Practice Reflection:
#   Using descriptive variable names such as user_name and primary_currency made the code easier to understand and maintain.
#
# Key Learning:
#   I learned that working through the problem step by step before coding made the program easier to implement and reduced mistakes.
# ...

# %% [markdown]
# ---
#
# ## Reflection on Industry Best Practices
#
#
# Using descriptive variable names and comments improved the readability of my program and made it easier to understand the purpose of each variable.
#
# Saving work frequently and using meaningful commit messages on GitHub helps track progress and prevents loss of work.
#
# Documenting my thought process using pseudocode and markdown cells helped clarify the logic before writing the code.
#
# ---
